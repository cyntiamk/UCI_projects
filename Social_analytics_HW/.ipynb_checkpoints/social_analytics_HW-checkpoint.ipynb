# %%
import tweepy
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json

from datetime import datetime
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()


from config import consumer_key, consumer_secret, access_token, access_token_secret

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# target users
target_users = ("BBCBreaking","CBSNews","CNN","FoxNews","nytimes")

results_list = []



for user in target_users:
    
    compound_list = []
    pos_list = []
    neu_list = []
    neg_list = []
    date_list = []
    channel_name = []
    counter = 0
    
    for x in range(1,6):
        public_tweets = api.user_timeline(user, page=x)
        
        for tweet in public_tweets:
            date = tweet["created_at"]
        
            results = analyzer.polarity_scores(tweet["text"])
            compound = results["compound"]
            pos = results["pos"]
            neu = results["neu"]
            neg = results["neg"]
            counter += 1
            results_list.append({
                "News Media": user,
                "Date": tweet["created_at"],
                "Compound": compound,
                "Positive": pos,
                "Neutral": neu,
                "Negative": neg,
                "Tweets Ago": counter})

# %%
df = pd.DataFrame(results_list)
results_df = df[["News Media","Date","Tweets Ago","Compound","Positive","Neutral","Negative"]]
results_df
# Out:
#       News Media                            Date  Tweets Ago  Compound  \
# 0    BBCBreaking  Sun Sep 09 18:09:57 +0000 2018           1    0.6249
# 1    BBCBreaking  Sun Sep 09 17:03:42 +0000 2018           2   -0.8555
# 2    BBCBreaking  Sat Sep 08 21:47:17 +0000 2018           3    0.8402
# 3    BBCBreaking  Sat Sep 08 17:02:27 +0000 2018           4   -0.9231
# 4    BBCBreaking  Sat Sep 08 09:38:43 +0000 2018           5   -0.7184
# 5    BBCBreaking  Sat Sep 08 09:10:30 +0000 2018           6   -0.0772
# 6    BBCBreaking  Fri Sep 07 21:28:58 +0000 2018           7   -0.6486
# 7    BBCBreaking  Fri Sep 07 20:45:14 +0000 2018           8   -0.7650
# 8    BBCBreaking  Fri Sep 07 07:00:15 +0000 2018           9   -0.7871
# 9    BBCBreaking  Thu Sep 06 20:55:50 +0000 2018          10   -0.8225
# 10   BBCBreaking  Thu Sep 06 19:28:33 +0000 2018          11    0.4019
# 11   BBCBreaking  Thu Sep 06 19:06:08 +0000 2018          12    0.0000
# 12   BBCBreaking  Thu Sep 06 17:00:22 +0000 2018          13   -0.2732
# 13   BBCBreaking  Thu Sep 06 15:10:53 +0000 2018          14    0.3245
# 14   BBCBreaking  Thu Sep 06 10:35:28 +0000 2018          15   -0.5574
# 15   BBCBreaking  Thu Sep 06 06:28:06 +0000 2018          16   -0.1280
# 16   BBCBreaking  Wed Sep 05 12:11:06 +0000 2018          17   -0.7351
# 17   BBCBreaking  Wed Sep 05 12:05:07 +0000 2018          18   -0.3400
# 18   BBCBreaking  Wed Sep 05 10:09:08 +0000 2018          19   -0.4767
# 19   BBCBreaking  Wed Sep 05 10:01:06 +0000 2018          20    0.7351
# 20   BBCBreaking  Tue Sep 04 16:23:45 +0000 2018          21    0.1779
# 21   BBCBreaking  Tue Sep 04 04:05:29 +0000 2018          22   -0.7906
# 22   BBCBreaking  Mon Sep 03 12:16:16 +0000 2018          23    0.0000
# 23   BBCBreaking  Mon Sep 03 07:14:50 +0000 2018          24   -0.0516
# 24   BBCBreaking  Mon Sep 03 04:08:27 +0000 2018          25   -0.6249
# 25   BBCBreaking  Mon Sep 03 00:43:10 +0000 2018          26    0.0258
# 26   BBCBreaking  Sun Sep 02 21:45:33 +0000 2018          27   -0.3400
# 27   BBCBreaking  Fri Aug 31 21:55:30 +0000 2018          28   -0.7003
# 28   BBCBreaking  Fri Aug 31 20:16:13 +0000 2018          29    0.4215
# 29   BBCBreaking  Fri Aug 31 19:54:02 +0000 2018          30    0.0000
# ..           ...                             ...         ...       ...
# 470      nytimes  Sun Sep 09 12:00:02 +0000 2018          71    0.0000
# 477     0.000    1.000     0.000
# 478     0.128    0.872     0.000
# 479     0.000    1.000     0.000
# 480     0.151    0.849     0.000
# 481     0.000    0.748     0.252
# 482     0.000    1.000     0.000
# 483     0.000    0.844     0.156
# 484     0.059    0.941     0.000
# 485     0.157    0.843     0.000
# 486     0.000    1.000     0.000
# 487     0.194    0.806     0.000
# 488     0.249    0.694     0.057
# 489     0.000    0.744     0.256
# 490     0.000    0.911     0.089
# 491     0.000    0.824     0.176
# 492     0.168    0.727     0.105
# 493     0.316    0.596     0.088
# 494     0.167    0.833     0.000
# 495     0.000    0.881     0.119
# 496     0.000    1.000     0.000
# 497     0.000    1.000     0.000
# 498     0.000    0.769     0.231
# 499     0.184    0.816     0.000
#
# [500 rows x 7 columns]

# %%
bbc = results_df.loc[results_df["News Media"] == "BBCBreaking",:]
bbc_x = bbc["Tweets Ago"]
bbc_y = bbc["Compound"]

cbs = results_df.loc[results_df["News Media"] == "CBSNews",:]
cbs_x = cbs["Tweets Ago"]
cbs_y = cbs["Compound"]

cnn = results_df.loc[results_df["News Media"] == "CNN",:]
cnn_x = cnn["Tweets Ago"]
cnn_y = cnn["Compound"]

fox = results_df.loc[results_df["News Media"] == "FoxNews",:]
fox_x = cbs["Tweets Ago"]
fox_y = cbs["Compound"]

nytimes = results_df.loc[results_df["News Media"] == "nytimes",:]
nytimes_x = cbs["Tweets Ago"]
nytimes_y = cbs["Compound"]

# %%
plt.figure(figsize=(10,5))
plt.scatter(bbc_x,bbc_y, c="skyblue", label="BBC", edgecolor="black",s=100)
plt.scatter(cbs_x,cbs_y, c="green", label="CBS", edgecolor="black",s=100)
plt.scatter(cnn_x,cnn_y, c="red", label="CNN", edgecolor="black",s=100)
plt.scatter(fox_x,fox_y, c="blue", label="Fox", edgecolor="black",s=100)
plt.scatter(nytimes_x,nytimes_y, c="yellow", label="NY Times", edgecolor="black",s=100)


plt.title("News Media Sentiment Analysis")
plt.xlabel("Tweets Ago")
plt.ylabel("Tweet Polarity")
plt.xlim(110,-5,20)
plt.ylim(-1.2,1.2,0.5)

plt.grid(True)
plt.legend( bbox_to_anchor=[1.3, 0.5], title="News Media")


plt.show()

# %%
cbs.head()
# Out:
#     News Media                            Date  Tweets Ago  Compound  \
# 100    CBSNews  Mon Sep 10 02:39:57 +0000 2018           1    0.4588
# 101    CBSNews  Mon Sep 10 02:04:43 +0000 2018           2   -0.7906
# 102    CBSNews  Mon Sep 10 01:39:57 +0000 2018           3    0.4019
# 103    CBSNews  Mon Sep 10 01:19:32 +0000 2018           4    0.3612
# 104    CBSNews  Mon Sep 10 00:54:44 +0000 2018           5    0.0772
#
#      Positive  Neutral  Negative
# 100     0.143    0.857     0.000
# 101     0.000    0.652     0.348
# 102     0.124    0.876     0.000
# 103     0.180    0.711     0.109
# 104     0.110    0.793     0.097

# %%
nytimes.head()
# Out:
#     News Media                            Date  Tweets Ago  Compound  \
# 400    nytimes  Mon Sep 10 02:56:24 +0000 2018           1   -0.5423
# 401    nytimes  Mon Sep 10 02:52:40 +0000 2018           2    0.0000
# 402    nytimes  Mon Sep 10 02:42:02 +0000 2018           3   -0.8470
# 403    nytimes  Mon Sep 10 02:28:41 +0000 2018           4    0.0000
# 404    nytimes  Mon Sep 10 02:19:54 +0000 2018           5    0.0000
#
#      Positive  Neutral  Negative
# 400       0.0    0.759     0.241
# 401       0.0    1.000     0.000
# 402       0.0    0.650     0.350
# 403       0.0    1.000     0.000
# 404       0.0    1.000     0.000
