# %% [markdown]
# # Observable Trends
# 1.
# 2.
# 3.

# %%
import tweepy
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json

from datetime import datetime
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()


from config import consumer_key, consumer_secret, access_token, access_token_secret

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# target users
target_users = ("BBCBreaking","CBSNews","CNN","FoxNews","nytimes")

results_list = []

for user in target_users:
    
    compound_list = []
    pos_list = []
    neu_list = []
    neg_list = []
    channel_name = []
    counter = 0
    
    
    for x in range(1):
        public_tweets = api.user_timeline(user, page=x, result_type="recent")
        
        for tweet in public_tweets:               
            results = analyzer.polarity_scores(tweet["text"])
            compound = results["compound"]
            pos = results["pos"]
            neu = results["neu"]
            neg = results["neg"]
                       
            counter += 1
    
            results_list.append({
                "News Media": user,
                "Date":tweet["created_at"],
                "Compound": compound,
                "Positive": pos,
                "Neutral": neu,
                "Negative": neg,
                "Tweets Ago": counter,
                "Tweet":tweet["text"]})

# %%
df = pd.DataFrame(results_list)

results_df =df[["News Media","Date","Tweets Ago","Compound","Positive","Neutral","Negative","Tweet"]]
results_df.head()
# Out:
#     News Media                            Date  Tweets Ago  Compound  \
# 0  BBCBreaking  Mon Sep 10 14:09:41 +0000 2018           1    0.0000
# 1  BBCBreaking  Mon Sep 10 11:45:36 +0000 2018           2    0.4374
# 2  BBCBreaking  Sun Sep 09 18:09:57 +0000 2018           3    0.6249
# 3  BBCBreaking  Sun Sep 09 17:03:42 +0000 2018           4   -0.8555
# 4  BBCBreaking  Sat Sep 08 21:47:17 +0000 2018           5    0.8402
#
#    Positive  Neutral  Negative  \
# 0     0.000    1.000     0.000
# 1     0.107    0.893     0.000
# 2     0.282    0.718     0.000
# 3     0.000    0.580     0.420
# 4     0.340    0.577     0.083
#
#                                                Tweet
# 0  England's leading Test run scorer Alastair Coo...
# 1  RT @bbctms: THERE IT IS!\nWhat a moment for Al...
# 2  Sweden's far right makes gains in election as ...
# 3  28-year-old woman charged with attempted murde...
# 4  Naomi Osaka beats Serena Williams 6-2 6-4 to w...

# %%
# Save dateframe to csv file
#results_df.to_csv("news_media_sentiment.csv")

# %%
bbc = df.loc[df["News Media"] == "BBCBreaking",:]
bbc_x = bbc["Tweets Ago"]
bbc_y = bbc["Compound"]

cbs = df.loc[df["News Media"] == "CBSNews",:]
cbs_x = cbs["Tweets Ago"]
cbs_y = cbs["Compound"]

cnn = df.loc[df["News Media"] == "CNN",:]
cnn_x = cnn["Tweets Ago"]
cnn_y = cnn["Compound"]

fox = df.loc[df["News Media"] == "FoxNews",:]
fox_x = fox["Tweets Ago"]
fox_y = fox["Compound"]

nytimes = df.loc[df["News Media"] == "nytimes",:]
nytimes_x = nytimes["Tweets Ago"]
nytimes_y = nytimes["Compound"]

# %%
plt.figure(figsize=(10,8))
plt.scatter(bbc_x,bbc_y, c="skyblue", label="BBC", edgecolor="black",s=150,alpha=0.75)
plt.scatter(cbs_x,cbs_y, c="green", label="CBS", edgecolor="black",s=150,alpha=0.75)
plt.scatter(cnn_x,cnn_y, c="red", label="CNN", edgecolor="black",s=150,alpha=0.75)
plt.scatter(fox_x,fox_y, c="blue", label="Fox", edgecolor="black",s=150,alpha=0.75)
plt.scatter(nytimes_x,nytimes_y, c="yellow", label="NY Times", edgecolor="black",s=150,alpha=0.75)


plt.title(f"News Media Sentiment Analysis based on Twitter()")
plt.xlabel("Tweets Ago")
plt.ylabel("Tweet Polarity")
plt.xlim(105,-5,20)
plt.ylim(-1.2,1.2,0.5)

plt.grid(True)
plt.legend(bbox_to_anchor=[1.2, 0.8], title="News Media")
#plt.savefig("media_sentiment_analysis.png")

plt.show()

# %%
grouped = results_df.groupby("News Media").mean()
compound_mean = grouped["Compound"]
colors="skyblue","green","red","blue","yellow"
xticks="BBC","CBS","CNN","Fox","NY Times"

# %%
compound_plot = compound_mean.plot(kind='bar',rot=0,
                                   color=colors,figsize=(10,8),
                                   edgecolor='black',width=1)
compound_plot.set_ylabel("Tweet Polarity")
compound_plot.set_title("Overall Media Sentiment based on Twitter ()")
#plt.savefig("overall_sentiment.png")
plt.show()
