# %% [markdown]
# # Observable Trends
#
# * The scatter plot Latitude vs. Temperature, proves that the closer you are to the equator the higher will the temperature be.
# * Surprisingly enough, the Latitude didn't seem to influence the Humidity. What we can see is that the northern hermisphere is slighlty more humid but that could also be a sign that the northern hemisphere is also more populated and developed.
# * Cloudiness and Wind Speed also don't seem to be affected by the Latitude. It would be relevant to include the elevation of the cities in order to have a better picture of the weather.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
# Import API key
#from config import api_key
api_key = "784200dc86b4d9e4679d3b9e6a86971f"
from citipy import citipy

# %% [markdown]
# ## Generate Cities List

# %%
# empty lists to store new variables found
lats_lons = []
cities = []

# latitude range is from -90 to 90
# longitude range is from -180 to 180
# select random number between latitude and longitude
lats = np.random.uniform(-90,90,1500)
lons = np.random.uniform(-180,180,1500)

# zip the two lists together to get random coordinates
lats_lons = zip(lats,lons)

# using random coordinates stored in lats_lons list,
# search citipy for city names using those random coordinates
for lat_lon in lats_lons:
    city_coord = citipy.nearest_city(lat_lon[0], lat_lon[1])
    city = city_coord.city_name
    # only append city name that is unique
    if city not in cities:
        cities.append(city)
        
# convert the cities list into a dataframe naming the column City        
cities_df = pd.DataFrame(cities)
# add columns header
cities_df.columns = ["City"]
# save dataframe as csv
cities_df.to_csv("cities.csv",index=True, header=True)

# group cities_df by city to be able to add city number using cumcount
cities_grouped =cities_df.groupby("City")

# using cumcount, create a new column starting at 1 instead of 0
cities_df["City Number"] = np.arange(1, len(cities_grouped.cumcount()) + 1)
cities_df.head()
# Out:
#            City  City Number
# 0    teneguiban            1
# 1  punta arenas            2
# 2       kahului            3
# 3       paamiut            4
# 4          axim            5

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# look at documentation, find out base url
base_url = "http://api.openweathermap.org/data/2.5/weather?"
# define unit desired
units = "imperial"

# create query url by adding to the base_url the api_key and the  units, 
# leave q= empty so we can iterate through the cities we got randomly
query_url = f"{base_url}appid={api_key}&units={units}&q="

# empty variables to be store during itertion to be used on plots requested
lon = []
lat = []
temp = []
hum = []
cloud = []
wind = []
country_code = []
date = []
names = []

# use iterrows to search for each city in the cities_df,
# requesting only the row with the city names
# the iterrows will also bring the city number columns when we print the cities 
# we are using to build this dataframe
for index,row in cities_df.iterrows(): 
    response = requests.get(query_url + row["City"]).json()
    # create exception in case the random names found in citypy is not found
    # in the query url
    try:
        # if the name is found, it will print the city number and city name
        print("Processing record #"+ str(row["City Number"])+" | " + str(row["City"]))  
        # using the same iterarion, we will fill out the empty variables create above
        names.append(response['name'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        hum.append(response['main']['humidity'])
        wind.append(response['wind']['speed'])
        cloud.append(response['clouds']['all'])
        country_code.append(response['sys']['country'])
        date.append(response['dt'])
        # if the city name is not found, it will print city not found..skipping instead.
    except(KeyError):
        print("---City not found---skipping....")
print("________________________________")
print("Processing complete!")
print("________________________________")
# Out:
# Processing record #1 | punta arenas
# Processing record #2 | cockburn town
# Processing record #3 | tasiilaq
# Processing record #4 | jacmel
# Processing record #5 | coihaique
# Processing record #6 | ushuaia
# Processing record #7 | jieshi
# Processing record #8 | illoqqortoormiut
# ---City not found---skipping....
# Processing record #9 | kozulka
# Processing record #10 | kurgan
# Processing record #11 | mataura
# Processing record #12 | castro
# Processing record #13 | oranjestad
# Processing record #14 | bathsheba
# Processing record #15 | klaksvik
# Processing record #16 | rikitea
# Processing record #17 | avarua
# Processing record #18 | hermanus
# Processing record #19 | middelburg
# Processing record #20 | bluff
# Processing record #21 | albany
# Processing record #22 | hobart
# Processing record #23 | arlit
# Processing record #24 | santa rosa
# Processing record #25 | kaitangata
# Processing record #26 | new norfolk
# Processing record #27 | marcona
# ---City not found---skipping....
# Processing record #28 | chuy
# Processing record #29 | podgorica
# Processing record #30 | carnarvon
# Processing record #31 | coquimbo
# Processing record #32 | hilo
# Processing record #33 | dunedin
# Processing record #34 | cayenne
# Processing record #35 | garowe
# Processing record #36 | cape town
# Processing record #37 | ulladulla
# Processing record #38 | bredasdorp
# Processing record #39 | vardo
# Processing record #40 | vaini
# Processing record #41 | burns lake
# Processing record #42 | khatanga
# Processing record #43 | mar del plata
# Processing record #44 | dalvik
# Processing record #45 | saryshagan
# ---City not found---skipping....
# Processing record #46 | port alfred
# Processing record #47 | mayumba
# Processing record #48 | sangar
# Processing record #49 | fort nelson
# Processing record #50 | amderma
# ---City not found---skipping....
# Processing record #51 | yellowknife
# Processing record #52 | aquin
# Processing record #53 | kemin
# Processing record #54 | paita
# Processing record #55 | busselton
# Processing record #56 | butaritari
# Processing record #57 | norman wells
# Processing record #58 | palana
# Processing record #59 | doctor pedro p. pena
# ---City not found---skipping....
# Processing record #60 | chicama
# Processing record #61 | mys shmidta
# ---City not found---skipping....
# Processing record #62 | olinda
# Processing record #63 | grimari
# ---City not found---skipping....
# Processing record #64 | fairbanks
# Processing record #65 | kananga
# Processing record #66 | gravdal
# Processing record #67 | arraial do cabo
# Processing record #68 | mega
# Processing record #69 | vestmanna
# Processing record #70 | mahina
# Processing record #71 | altonia
# ---City not found---skipping....
# Processing record #72 | chenghai
# Processing record #73 | touros
# Processing record #74 | tumannyy
# ---City not found---skipping....
# Processing record #75 | corn island
# Processing record #76 | nemuro
# Processing record #77 | ogaminana
# Processing record #78 | gallup
# Processing record #79 | hithadhoo
# Processing record #80 | lensk
# Processing record #81 | taolanaro
# ---City not found---skipping....
# Processing record #82 | camabatela
# Processing record #83 | wawa
# Processing record #84 | tutoia
# Processing record #85 | port elizabeth
# Processing record #86 | esperance
# Processing record #87 | atuona
# Processing record #88 | tuatapere
# Processing record #89 | caravelas
# Processing record #90 | faanui
# Processing record #91 | port lincoln
# Processing record #92 | bethel
# Processing record #93 | ossora
# Processing record #94 | shu
# Processing record #95 | mago
# Processing record #96 | kodiak
# Processing record #97 | cidreira
# Processing record #98 | saleaula
# ---City not found---skipping....
# Processing record #99 | mpulungu
# Processing record #100 | torbay
# Processing record #101 | benghazi
# Processing record #102 | hambantota
# Processing record #103 | revelstoke
# Processing record #104 | taoudenni
# Processing record #105 | hranice
# Processing record #106 | urman
# Processing record #107 | nanortalik
# Processing record #108 | macusani
# Processing record #109 | kapaa
# Processing record #110 | mangrol
# Processing record #111 | ribeira brava
# Processing record #112 | gamboula
# Processing record #113 | pokaran
# Processing record #114 | puerto suarez
# Processing record #115 | pemangkat
# ---City not found---skipping....
# Processing record #116 | noumea
# Processing record #117 | isangel
# Processing record #118 | okhotsk
# Processing record #119 | seoul
# Processing record #120 | urbano santos
# Processing record #121 | ziro
# Processing record #122 | jiaocheng
# Processing record #123 | ilhabela
# Processing record #124 | rabo de peixe
# Processing record #125 | krasnoselkup
# ---City not found---skipping....
# Processing record #126 | guamuchil
# Processing record #127 | ilulissat
# Processing record #128 | durban
# Processing record #129 | samusu
# ---City not found---skipping....
# Processing record #130 | varhaug
# Processing record #131 | barentsburg
# ---City not found---skipping....
# Processing record #132 | milverton
# Processing record #133 | rio gallegos
# Processing record #134 | puerto ayora
# Processing record #135 | biloela
# Processing record #136 | itarema
# Processing record #137 | lebu
# Processing record #138 | naze
# Processing record #139 | skibbereen
# Processing record #140 | tazovskiy
# Processing record #141 | makat
# Processing record #142 | banjarmasin
# Processing record #143 | taltal
# Processing record #144 | westport
# Processing record #145 | khakhea
# Processing record #146 | batie
# Processing record #147 | dicabisagan
# Processing record #148 | bambous virieux
# Processing record #149 | dubenskiy
# ---City not found---skipping....
# Processing record #150 | zheleznodorozhnyy
# Processing record #151 | tuktoyaktuk
# Processing record #152 | rawson
# Processing record #153 | cherskiy
# Processing record #154 | cabras
# Processing record #155 | christchurch
# Processing record #156 | grand river south east
# ---City not found---skipping....
# Processing record #157 | ballitoville
# Processing record #158 | los llanos de aridane
# Processing record #159 | burnie
# Processing record #160 | imeni poliny osipenko
# Processing record #161 | attawapiskat
# ---City not found---skipping....
# Processing record #162 | aksu
# Processing record #163 | paamiut
# Processing record #164 | ginir
# Processing record #165 | saskylakh
# Processing record #166 | shakawe
# Processing record #167 | morondava
# Processing record #168 | aklavik
# Processing record #169 | jamestown
# Processing record #170 | bur gabo
# ---City not found---skipping....
# Processing record #171 | makakilo city
# Processing record #172 | puerto escondido
# Processing record #173 | mnogovershinnyy
# Processing record #174 | salme
# Processing record #175 | souillac
# Processing record #176 | richards bay
# Processing record #177 | puerto colombia
# Processing record #178 | neiafu
# Processing record #179 | kendari
# Processing record #180 | ponta do sol
# Processing record #181 | shimoda
# Processing record #182 | paytug
# ---City not found---skipping....
# Processing record #183 | half moon bay
# Processing record #184 | beringovskiy
# Processing record #185 | asau
# ---City not found---skipping....
# Processing record #186 | sioux lookout
# Processing record #187 | timra
# Processing record #188 | mehran
# Processing record #189 | saint-philippe
# Processing record #190 | big rapids
# Processing record #191 | severo-kurilsk
# Processing record #192 | mwanza
# Processing record #193 | karaul
# ---City not found---skipping....
# Processing record #194 | husavik
# Processing record #195 | tabiauea
# ---City not found---skipping....
# Processing record #196 | lagoa
# Processing record #197 | katsuura
# Processing record #198 | bambanglipuro
# Processing record #199 | casma
# Processing record #200 | kulim
# Processing record #201 | yumen
# Processing record #202 | nantucket
# Processing record #203 | nandu
# Processing record #204 | mayo
# Processing record #205 | kavieng
# Processing record #206 | mount gambier
# Processing record #207 | bengkulu
# ---City not found---skipping....
# Processing record #208 | svetlogorsk
# Processing record #209 | gushikawa
# Processing record #210 | prince rupert
# Processing record #211 | swellendam
# Processing record #212 | haines junction
# Processing record #213 | ambodifototra
# ---City not found---skipping....
# Processing record #214 | bilibino
# Processing record #215 | codrington
# Processing record #216 | togur
# Processing record #217 | saldanha
# Processing record #218 | vila franca do campo
# Processing record #219 | boende
# Processing record #220 | nikolskoye
# Processing record #221 | guiren
# Processing record #222 | pevek
# Processing record #223 | wanaka
# Processing record #224 | hoi an
# Processing record #225 | bilma
# Processing record #226 | lavrentiya
# Processing record #227 | faya
# Processing record #228 | longyearbyen
# Processing record #229 | lompoc
# Processing record #230 | kruisfontein
# Processing record #231 | huilong
# Processing record #232 | chokurdakh
# Processing record #233 | saint george
# Processing record #234 | saint anthony
# Processing record #235 | buarcos
# Processing record #236 | victoria
# Processing record #237 | miastko
# Processing record #238 | huescar
# Processing record #239 | komsomolskiy
# Processing record #240 | vaitupu
# ---City not found---skipping....
# Processing record #241 | saint-pierre
# Processing record #242 | narsaq
# Processing record #243 | provideniya
# Processing record #244 | east london
# Processing record #245 | guerrero negro
# Processing record #246 | fare
# Processing record #247 | port macquarie
# Processing record #248 | iqaluit
# Processing record #249 | kamaishi
# Processing record #250 | clearwater
# Processing record #251 | nogliki
# Processing record #252 | sibut
# Processing record #253 | sladkovo
# Processing record #254 | psebay
# Processing record #255 | marshall
# Processing record #256 | lorengau
# Processing record #257 | pisco
# Processing record #258 | gazojak
# Processing record #259 | bongaree
# Processing record #260 | hirara
# Processing record #261 | malavalli
# Processing record #262 | jacareacanga
# Processing record #263 | fort madison
# Processing record #264 | belmonte
# Processing record #265 | airai
# Processing record #266 | evensk
# Processing record #267 | esik
# Processing record #268 | diapaga
# Processing record #269 | hohhot
# Processing record #270 | banjar
# Processing record #271 | kismayo
# ---City not found---skipping....
# Processing record #272 | srednekolymsk
# Processing record #273 | tiksi
# Processing record #274 | mbala
# Processing record #275 | taitung
# Processing record #276 | linchuan
# ---City not found---skipping....
# Processing record #277 | atikokan
# Processing record #278 | amuntai
# Processing record #279 | uspenka
# Processing record #280 | vila
# Processing record #281 | hobyo
# Processing record #282 | kahului
# Processing record #283 | nakusp
# Processing record #284 | qaanaaq
# Processing record #285 | constitucion
# Processing record #286 | mahebourg
# Processing record #287 | barrow
# Processing record #288 | suffolk
# Processing record #289 | hofn
# Processing record #290 | la ronge
# Processing record #291 | quatre cocos
# Processing record #292 | chadiza
# Processing record #293 | myitkyina
# Processing record #294 | hegang
# Processing record #295 | klyuchi
# Processing record #296 | pedernales
# Processing record #297 | gazli
# Processing record #298 | dikson
# Processing record #299 | bintulu
# Processing record #300 | spantov
# Processing record #301 | tigil
# Processing record #302 | anadyr
# Processing record #303 | adrar
# Processing record #304 | cozumel
# ---City not found---skipping....
# Processing record #305 | sorong
# Processing record #306 | ntungamo
# Processing record #307 | amapa
# Processing record #308 | leh
# Processing record #309 | khotiv
# Processing record #310 | praia da vitoria
# Processing record #311 | kitui
# Processing record #312 | grindavik
# Processing record #313 | qui nhon
# ---City not found---skipping....
# Processing record #314 | hay river
# Processing record #315 | ponta delgada
# Processing record #316 | zapolyarnyy
# Processing record #317 | salalah
# Processing record #318 | porirua
# Processing record #319 | naftah
# ---City not found---skipping....
# Processing record #320 | vallenar
# Processing record #321 | chimbote
# Processing record #322 | erdenet
# Processing record #323 | thompson
# Processing record #324 | libertador general san martin
# Processing record #325 | eyl
# Processing record #326 | port blair
# Processing record #327 | broome
# Processing record #328 | mpanda
# Processing record #329 | inhambane
# Processing record #330 | luocheng
# Processing record #331 | baghdad
# Processing record #332 | oistins
# Processing record #333 | bulgan
# Processing record #334 | belgrade
# Processing record #335 | ancud
# Processing record #336 | ovre ardal
# Processing record #337 | tougue
# Processing record #338 | algiers
# Processing record #339 | palabuhanratu
# ---City not found---skipping....
# Processing record #340 | san patricio
# Processing record #341 | bucerias
# Processing record #342 | laguna
# Processing record #343 | san ignacio
# Processing record #344 | edd
# Processing record #345 | buqayq
# ---City not found---skipping....
# Processing record #346 | sentyabrskiy
# ---City not found---skipping....
# Processing record #347 | waipawa
# Processing record #348 | kirakira
# Processing record #349 | gorno-chuyskiy
# ---City not found---skipping....
# Processing record #350 | nizhneyansk
# ---City not found---skipping....
# Processing record #351 | hamilton
# Processing record #352 | dakar
# Processing record #353 | ribeira grande
# Processing record #354 | atbasar
# Processing record #355 | angoche
# Processing record #356 | sao filipe
# Processing record #357 | tongliao
# Processing record #358 | shache
# Processing record #359 | bereda
# Processing record #360 | gari
# Processing record #361 | petropavlovsk-kamchatskiy
# Processing record #362 | dunda
# Processing record #363 | sinnamary
# Processing record #364 | cabo san lucas
# Processing record #365 | mazyr
# Processing record #366 | virginia beach
# Processing record #367 | tortosa
# Processing record #368 | chimbarongo
# Processing record #369 | berlevag
# Processing record #370 | tambo
# Processing record #371 | stepnyak
# Processing record #372 | clyde river
# Processing record #373 | nichinan
# Processing record #374 | jiangyou
# Processing record #375 | msanga
# Processing record #376 | kerava
# Processing record #377 | dalgopol
# ---City not found---skipping....
# Processing record #378 | bratsk
# Processing record #379 | hof
# Processing record #380 | marawi
# Processing record #381 | cam ranh
# Processing record #382 | galesong
# Processing record #383 | vadso
# Processing record #384 | belushya guba
# ---City not found---skipping....
# Processing record #385 | tautira
# Processing record #386 | scarborough
# Processing record #387 | deputatskiy
# Processing record #388 | jablah
# Processing record #389 | bata
# Processing record #390 | nouadhibou
# Processing record #391 | isilkul
# Processing record #392 | dhidhdhoo
# Processing record #393 | eldorado
# Processing record #394 | flin flon
# Processing record #395 | lincoln
# Processing record #396 | athabasca
# Processing record #397 | kizhinga
# Processing record #398 | makkaveyevo
# Processing record #399 | kavaratti
# Processing record #400 | akashi
# Processing record #401 | krabi
# Processing record #402 | yarmouth
# Processing record #403 | port hardy
# Processing record #404 | atambua
# Processing record #405 | daru
# Processing record #406 | puerto guzman
# Processing record #407 | karratha
# Processing record #408 | mocambique
# ---City not found---skipping....
# Processing record #409 | capoeiras
# Processing record #410 | comodoro rivadavia
# Processing record #411 | zwedru
# Processing record #412 | tupik
# Processing record #413 | beatrice
# Processing record #414 | kenai
# Processing record #415 | jilib
# Processing record #416 | dustlik
# Processing record #417 | kashipur
# Processing record #418 | matay
# Processing record #419 | slonim
# Processing record #420 | kedrovyy
# Processing record #421 | batemans bay
# Processing record #422 | chambersburg
# Processing record #423 | kudahuvadhoo
# Processing record #424 | felanitx
# Processing record #425 | ivanava
# Processing record #426 | thessalon
# Processing record #427 | weinan
# Processing record #428 | phan thiet
# Processing record #429 | talcahuano
# Processing record #430 | zanjan
# Processing record #431 | georgetown
# Processing record #432 | oranjemund
# Processing record #433 | klobuck
# Processing record #434 | paidha
# Processing record #435 | alofi
# Processing record #436 | kyren
# Processing record #437 | ahipara
# Processing record #438 | kilindoni
# Processing record #439 | nome
# Processing record #440 | peniche
# Processing record #441 | tromso
# Processing record #442 | ituni
# ---City not found---skipping....
# Processing record #443 | oum hadjer
# Processing record #444 | sukhothai
# Processing record #445 | sawtell
# Processing record #446 | araouane
# Processing record #447 | ordynskoye
# Processing record #448 | vila velha
# Processing record #449 | bandarbeyla
# Processing record #450 | baturaja
# Processing record #451 | marsh harbour
# Processing record #452 | cangucu
# Processing record #453 | general roca
# Processing record #454 | talara
# Processing record #455 | baykit
# Processing record #456 | darhan
# Processing record #457 | grand gaube
# Processing record #458 | nioro
# Processing record #459 | halalo
# ---City not found---skipping....
# Processing record #460 | itoman
# Processing record #461 | north bend
# Processing record #462 | tilichiki
# Processing record #463 | mbaiki
# Processing record #464 | mount isa
# Processing record #465 | pucallpa
# Processing record #466 | kjollefjord
# Processing record #467 | san cristobal
# Processing record #468 | lac du bonnet
# Processing record #469 | teneguiban
# ---City not found---skipping....
# Processing record #470 | yelkhovka
# Processing record #471 | sydney
# Processing record #472 | san lorenzo
# Processing record #473 | hasaki
# Processing record #474 | leningradskiy
# Processing record #475 | tessalit
# Processing record #476 | el vendrell
# Processing record #477 | pinsk
# Processing record #478 | feicheng
# Processing record #479 | nishihara
# Processing record #480 | upernavik
# Processing record #481 | tiznit
# Processing record #482 | saysain
# Processing record #483 | presidente medici
# Processing record #484 | wichita falls
# Processing record #485 | langsa
# Processing record #486 | lamar
# Processing record #487 | itamaraju
# Processing record #488 | samsun
# Processing record #489 | quelimane
# Processing record #490 | villa union
# Processing record #491 | da lat
# Processing record #492 | penzance
# Processing record #493 | conceicao do araguaia
# Processing record #494 | charlestown
# Processing record #495 | sambava
# Processing record #496 | turiacu
# Processing record #497 | aberdeen
# Processing record #498 | zhigansk
# Processing record #499 | brus laguna
# Processing record #500 | cap malheureux
# Processing record #501 | muisne
# Processing record #502 | kerrville
# Processing record #503 | aracaju
# Processing record #504 | zelenoborskiy
# Processing record #505 | geraldton
# Processing record #506 | ternate
# Processing record #507 | marabba
# Processing record #508 | santiago de chuco
# Processing record #509 | muros
# Processing record #510 | tual
# Processing record #511 | dalby
# Processing record #512 | takasaki
# Processing record #513 | kerouane
# Processing record #514 | henties bay
# Processing record #515 | tarsus
# Processing record #516 | alappuzha
# ---City not found---skipping....
# Processing record #517 | port hedland
# Processing record #518 | saint-leu
# Processing record #519 | esna
# Processing record #520 | port moresby
# Processing record #521 | humaita
# Processing record #522 | cairns
# Processing record #523 | salinas
# Processing record #524 | te anau
# Processing record #525 | honiara
# Processing record #526 | svetla nad sazavou
# Processing record #527 | nago
# Processing record #528 | san jeronimo
# Processing record #529 | matsanga
# ---City not found---skipping....
# Processing record #530 | avera
# Processing record #531 | chupa
# Processing record #532 | bonavista
# Processing record #533 | hami
# Processing record #534 | kijang
# Processing record #535 | garautha
# Processing record #536 | ruatoria
# ---City not found---skipping....
# Processing record #537 | phangnga
# Processing record #538 | fortuna
# Processing record #539 | honggang
# Processing record #540 | tezu
# Processing record #541 | vysokogornyy
# Processing record #542 | waddan
# Processing record #543 | plyussa
# Processing record #544 | port-gentil
# Processing record #545 | kano
# Processing record #546 | floro
# Processing record #547 | tura
# Processing record #548 | pa daet
# Processing record #549 | inuvik
# Processing record #550 | kalemie
# Processing record #551 | peyima
# Processing record #552 | nuuk
# Processing record #553 | beloha
# Processing record #554 | sidi ali
# Processing record #555 | bolungarvik
# ---City not found---skipping....
# Processing record #556 | bafia
# Processing record #557 | santa maria
# Processing record #558 | itaquyry
# Processing record #559 | wagar
# Processing record #560 | gusau
# Processing record #561 | san quintin
# Processing record #562 | marrakesh
# Processing record #563 | akdepe
# Processing record #564 | merauke
# Processing record #565 | totness
# Processing record #566 | walvis bay
# Processing record #567 | lira
# Processing record #568 | urubicha
# Processing record #569 | fereydun kenar
# Processing record #570 | ixtapa
# Processing record #571 | nguiu
# ---City not found---skipping....
# Processing record #572 | kamenskoye
# ---City not found---skipping....
# Processing record #573 | vao
# Processing record #574 | tevaitoa
# Processing record #575 | linqu
# Processing record #576 | jalu
# Processing record #577 | zeya
# Processing record #578 | ngukurr
# ---City not found---skipping....
# Processing record #579 | impfondo
# Processing record #580 | veraval
# Processing record #581 | filadelfia
# Processing record #582 | bundibugyo
# Processing record #583 | trairi
# Processing record #584 | babushkin
# Processing record #585 | satitoa
# ---City not found---skipping....
# Processing record #586 | kasongo
# Processing record #587 | novato
# Processing record #588 | kununurra
# Processing record #589 | limbang
# Processing record #590 | uyo
# Processing record #591 | umm lajj
# Processing record #592 | acapulco
# Processing record #593 | lata
# Processing record #594 | andenes
# ---City not found---skipping....
# Processing record #595 | winslow
# Processing record #596 | bodden town
# Processing record #597 | bani walid
# Processing record #598 | narovchat
# Processing record #599 | parati
# Processing record #600 | mayskiy
# Processing record #601 | mildura
# Processing record #602 | fauske
# Processing record #603 | mitsamiouli
# Processing record #604 | sibiti
# Processing record #605 | boa vista
# Processing record #606 | lieksa
# Processing record #607 | manosque
# Processing record #608 | lerwick
# Processing record #609 | sitka

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# using the variables extracted from the query url,
# we built a dictionary, and from that dictionary
# we built a dataframe and saved as csv
weather_dict = {"City":names,
                "Country":country_code,
                "Latitude":lat,
                "Longitude":lon,
                "Temperature(F)":temp,
                "Humidity(%)":hum,
                "Cloudiness(%)": cloud, 
                "Wind Speed(MPH)":wind,
                "Date":date}
weather_df = pd.DataFrame(weather_dict)
# converted the time in seconds to a more readable format
weather_df["Date"] = pd.to_datetime(weather_df["Date"],unit="s")

weather_df.to_csv("weather.csv")
weather_df.head()

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# created scatter plots as requested
plt.scatter(weather_df["Latitude"],weather_df["Temperature(F)"],alpha=0.5,
            s=weather_df["Temperature(F)"], edgecolor="black")
plt.title("Latitude vs. Temperature(F) on 09/03/2018")
plt.xlabel("Latitude")
plt.ylabel("Temperature(F)")
plt.grid()
plt.savefig("latVStemp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# created scatter plot and set the ylim to avoid showing outliers
# used the bubble size to see 
plt.scatter(weather_df["Latitude"],weather_df["Humidity(%)"],s=weather_df["Humidity(%)"],
            alpha=0.5,edgecolor="black")
plt.title("Latitude vs. Humidity(%) on 09/03/2018")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.ylim(0,110)
plt.grid()
plt.savefig("latVShum.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Latitude"],weather_df["Cloudiness(%)"],s=weather_df["Cloudiness(%)"],
            alpha=0.5,edgecolor="black")
plt.title("Latitude vs. Cloudiness(%) on 09/03/2018")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.grid()
plt.savefig("latVScloud.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# created scatter plot and set ylim to exclude outliers
plt.scatter(weather_df["Latitude"],weather_df["Wind Speed(MPH)"],
            alpha=0.5,edgecolor="black")
plt.title("Latitude vs. Wind Speed(MPH) on 09/03/2018")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed(MPH)")
plt.ylim(-1,32)
plt.grid()
plt.savefig("latVSwind.png")
plt.show()
